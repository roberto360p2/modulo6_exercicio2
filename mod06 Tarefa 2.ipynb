# %% [markdown]
# # Módulo 06 Tarefa 2

# %% [markdown]
# # Indice <a name = "Contens"></a>
#
# 0. [importando pacotes](#0)
# 1. [Exercicio](#1)
# 2. [Exercicio](#2)
# 3. [Exercicio](#3)
# 4. [Exercicio](#4)

# %% [markdown]
# # <font color = "Green"> **Importando pacotes** <a name = "0"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
base = pd.read_csv(r"b1abb33c4f.csv",sep=",",encoding="utf8")
base.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# # <font color = "Green"> **Exercicio1** <a name = "0"></a>

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
plt.close("all")

sns.boxplot(y="IDADEMAE",data=base)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='IDADEMAE'>

# %% [markdown]
# # <font color = "Green"> **Exercicio2** <a name = "0"></a>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
plt.close("all")

base[["PESO"]].boxplot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# # <font color = "Green"> **Exercicio3** <a name = "0"></a>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
plt.close("all")
plt.hist(base["IDADEMAE"])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([5.520e+02, 4.006e+03, 5.830e+03, 5.980e+03, 4.789e+03, 4.094e+03,
#         1.435e+03, 3.200e+02, 1.800e+01, 4.000e+00]),
#  array([11. , 15.2, 19.4, 23.6, 27.8, 32. , 36.2, 40.4, 44.6, 48.8, 53. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # <font color = "Green"> **Exercicio4** <a name = "0"></a>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
plt.close("all")
sns.histplot(x="PESO",data=base,color="red")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='PESO', ylabel='Count'>
